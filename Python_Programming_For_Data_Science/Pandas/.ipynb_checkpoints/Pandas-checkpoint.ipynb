# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
s = pd.Series([1,2,3,4,5])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.size
# Out:
# 5

# %%
s.ndim
# Out:
# 1

# %%
s.values
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
titanic = sns.load_dataset("titanic")
df = titanic.copy()
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.describe().T
# Out:
#           count       mean        std   min      25%      50%   75%       max
# survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# sibsp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df["sex"].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
df[0:13]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
df.drop(0, axis = 0).head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True

# %%
drop_list = [2,3,4,5]
df.drop(drop_list, axis = 0).head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 6         0       1    male  54.0      0      0  51.8625        S  First
# 7         0       3    male   2.0      3      1  21.0750        S  Third
# 8         1       3  female  27.0      0      2  11.1333        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False

# %%
df.drop(drop_list, axis = 0, inplace = True)

# %% [markdown]
# ##### Converting variable to index

# %%
df["age"].head()
# Out:
# 0    22.0
# 1    38.0
# 6    54.0
# 7     2.0
# 8    27.0
# Name: age, dtype: float64

# %%
df.age.head()
# Out:
# 0    22.0
# 1    38.0
# 6    54.0
# 7     2.0
# 8    27.0
# Name: age, dtype: float64

# %%
df.index = df["age"]

# %%
df.drop(["age"], axis = 1).head()
# Out:
#       survived  pclass     sex  sibsp  parch     fare embarked  class    who  \
# age
# 22.0         0       3    male      1      0   7.2500        S  Third    man
# 38.0         1       1  female      1      0  71.2833        C  First  woman
# 54.0         0       1    male      0      0  51.8625        S  First    man
# 2.0          0       3    male      3      1  21.0750        S  Third  child
# 27.0         1       3  female      0      2  11.1333        S  Third  woman
#
#       adult_male deck  embark_town alive  alone
# age
# 22.0        True  NaN  Southampton    no  False
# 38.0       False    C    Cherbourg   yes  False
# 54.0        True    E  Southampton    no   True
# 2.0        False  NaN  Southampton    no  False
# 27.0       False  NaN  Southampton   yes  False

# %%
df.drop(["age"], axis = 1, inplace = True)

# %% [markdown]
# ##### Convert index to variable

# %%
df.index
# Out:
# Float64Index([22.0, 38.0, 54.0,  2.0, 27.0, 14.0,  4.0, 58.0, 20.0, 39.0,
#               ...
#               33.0, 22.0, 28.0, 25.0, 39.0, 27.0, 19.0,  nan, 26.0, 32.0],
#              dtype='float64', name='age', length=887)

# %%
df["age"] = df.index

# %%
"age" in df
# Out:
# True

# %%
df[['age']].head()
# Out:
#        age
# age
# 22.0  22.0
# 38.0  38.0
# 54.0  54.0
# 2.0    2.0
# 27.0  27.0

# %%
df[["age", "alive"]].head()
# Out:
#        age alive
# age
# 22.0  22.0    no
# 38.0  38.0   yes
# 54.0  54.0    no
# 2.0    2.0    no
# 27.0  27.0   yes

# %%
colnames = ["age", "alive", "adult_male"]

# %%
df[colnames].head()
# Out:
#        age alive  adult_male
# age
# 22.0  22.0    no        True
# 38.0  38.0   yes       False
# 54.0  54.0    no        True
# 2.0    2.0    no       False
# 27.0  27.0   yes       False

# %%
df["age2"] = df["age"] ** 2
df["age3"] = df["age"] / df["age2"]

# %%
df.drop("age3", axis =1, inplace = True)

# %%
df.drop(colnames, axis = 1).head()
# Out:
#       survived  pclass     sex  sibsp  parch     fare embarked  class    who  \
# age
# 22.0         0       3    male      1      0   7.2500        S  Third    man
# 38.0         1       1  female      1      0  71.2833        C  First  woman
# 54.0         0       1    male      0      0  51.8625        S  First    man
# 2.0          0       3    male      3      1  21.0750        S  Third  child
# 27.0         1       3  female      0      2  11.1333        S  Third  woman
#
#      deck  embark_town  alone    age2
# age
# 22.0  NaN  Southampton  False   484.0
# 38.0    C    Cherbourg  False  1444.0
# 54.0    E  Southampton   True  2916.0
# 2.0   NaN  Southampton  False     4.0
# 27.0  NaN  Southampton  False   729.0

# %%
df.loc[:, ~df.columns.str.contains("age")]
# Out:
#       survived  pclass     sex  sibsp  parch     fare embarked   class    who  \
# age
# 22.0         0       3    male      1      0   7.2500        S   Third    man
# 38.0         1       1  female      1      0  71.2833        C   First  woman
# 54.0         0       1    male      0      0  51.8625        S   First    man
# 2.0          0       3    male      3      1  21.0750        S   Third  child
# 27.0         1       3  female      0      2  11.1333        S   Third  woman
# ...        ...     ...     ...    ...    ...      ...      ...     ...    ...
# 27.0         0       2    male      0      0  13.0000        S  Second    man
# 19.0         1       1  female      0      0  30.0000        S   First  woman
# NaN          0       3  female      1      2  23.4500        S   Third  woman
# 26.0         1       1    male      0      0  30.0000        C   First    man
# 32.0         0       3    male      0      0   7.7500        Q   Third    man
#
# ...

# %%
df = titanic.copy()
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ##### iloc integer location

# %%
df.iloc[0:3]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
df.iloc[0, 0]
# Out:
# 0

# %% [markdown]
# ##### loc label based indexing

# %%
df.loc[0:3]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False

# %%
df.iloc[0:3, 0:3]
# Out:
#    survived  pclass     sex
# 0         0       3    male
# 1         1       1  female
# 2         1       3  female

# %%
df.loc[0:3, "age"]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# Name: age, dtype: float64

# %%
df.loc[0:3, ["age","who"]]
# Out:
#     age    who
# 0  22.0    man
# 1  38.0  woman
# 2  26.0  woman
# 3  35.0  woman

# %%
col_names = ["age", "embarked", "alive"]

df.loc[0:3, col_names]
# Out:
#     age embarked alive
# 0  22.0        S    no
# 1  38.0        C   yes
# 2  26.0        S   yes
# 3  35.0        S   yes

# %% [markdown]
# ##### Conditional Selections

# %%
df[df["age"] > 50].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 33         0       2    male  66.0      0      0  10.5000        S  Second
# 54         0       1    male  65.0      0      1  61.9792        C   First
#
#       who  adult_male deck  embark_town alive  alone
# 6     man        True    E  Southampton    no   True
# 11  woman       False    C  Southampton   yes   True
# 15  woman       False  NaN  Southampton   yes   True
# 33    man        True  NaN  Southampton    no   True
# 54    man        True    B    Cherbourg    no  False

# %%
df[df["age"] > 50].count()
# Out:
# survived       64
# pclass         64
# sex            64
# age            64
# sibsp          64
# parch          64
# fare           64
# embarked       63
# class          64
# who            64
# adult_male     64
# deck           33
# embark_town    63
# alive          64
# alone          64
# dtype: int64

# %%
df[df["age"] > 50]["age"].count()
# Out:
# 64

# %%
df.loc[df["age"] > 50, ["age", "class"]].head()
# Out:
#      age   class
# 6   54.0   First
# 11  58.0   First
# 15  55.0  Second
# 33  66.0  Second
# 54  65.0   First

# %%
# For multiple conditions (&) is used and parentheses are used
df.loc[(df["age"] > 50) & (df["sex"] == "male"), ["age", "class"]].head()
# Out:
#      age   class
# 6   54.0   First
# 33  66.0  Second
# 54  65.0   First
# 94  59.0   Third
# 96  71.0   First

# %%
df_new = df.loc[(df["age"] > 50) 
       & (df["sex"] == "male") 
       & ((df["embark_town"]== "Southampton") | (df["embark_town"]== "Cherbourg")), 
       ["age", "class", "embark_town"]].head()

# %%
df["embark_town"].value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
df_new["embark_town"].value_counts()
# Out:
# Southampton    3
# Cherbourg      2
# Name: embark_town, dtype: int64

# %% [markdown]
# ##### Aggregation and Grouping Operations

# %%
df["age"].mean()
# Out:
# 29.69911764705882

# %%
df.groupby("sex")["age"].mean()
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %%
df.groupby("sex").agg({"age":"mean"})
# Out:
#               age
# sex
# female  27.915709
# male    30.726645

# %%
df.groupby("sex").agg({"age":["mean", "max", "min"],
                       "fare":["mean", "sum", "max"]})
# Out:
#               age                   fare
#              mean   max   min       mean         sum       max
# sex
# female  27.915709  63.0  0.75  44.479818  13966.6628  512.3292
# male    30.726645  80.0  0.42  25.523893  14727.2865  512.3292

# %%
df.groupby(["sex", "embark_town", "class"]).agg({"age":["mean"],
                       "survived":["mean"]})
# Out:
#                                  age  survived
#                                 mean      mean
# sex    embark_town class
# female Cherbourg   First   36.052632  0.976744
#                    Second  19.142857  1.000000
#                    Third   14.062500  0.652174
#        Queenstown  First   33.000000  1.000000
#                    Second  30.000000  1.000000
#                    Third   22.850000  0.727273
#        Southampton First   32.704545  0.958333
#                    Second  29.719697  0.910448
#                    Third   23.223684  0.375000
# male   Cherbourg   First   40.111111  0.404762
#                    Second  25.937500  0.200000
#                    Third   25.016800  0.232558
#        Queenstown  First   44.000000  0.000000
#                    Second  57.000000  0.000000
#                    Third   28.142857  0.076923
#        Southampton First   41.897188  0.354430
#                    Second  30.875889  0.154639
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.groupby(["sex", "embark_town", "class"]).agg({"age":["mean"],
                       "survived":["mean"],
                       "sex":["count"]})
# Out:
#                                  age  survived   sex
#                                 mean      mean count
# sex    embark_town class
# female Cherbourg   First   36.052632  0.976744    43
#                    Second  19.142857  1.000000     7
#                    Third   14.062500  0.652174    23
#        Queenstown  First   33.000000  1.000000     1
#                    Second  30.000000  1.000000     2
#                    Third   22.850000  0.727273    33
#        Southampton First   32.704545  0.958333    48
#                    Second  29.719697  0.910448    67
#                    Third   23.223684  0.375000    88
# male   Cherbourg   First   40.111111  0.404762    42
#                    Second  25.937500  0.200000    10
#                    Third   25.016800  0.232558    43
#        Queenstown  First   44.000000  0.000000     1
#                    Second  57.000000  0.000000     1
#                    Third   28.142857  0.076923    39
# ...

# %% [markdown]
# ##### Pivot table

# %%
df = titanic.copy()
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.pivot_table("survived", "sex", ["embarked", "class"])
# Out:
# embarked         C                      Q                          S  \
# class        First Second     Third First Second     Third     First
# sex
# female    0.976744    1.0  0.652174   1.0    1.0  0.727273  0.958333
# male      0.404762    0.2  0.232558   0.0    0.0  0.076923  0.354430
#
# embarked
# class       Second     Third
# sex
# female    0.910448  0.375000
# male      0.154639  0.128302

# %%
# Creating a categorical variable with the cut function
# Creating an evenly spaced categorical variable with qcut
df["new_age"] = pd.cut(df["age"], [0,10,18,25,40,90])
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone   new_age
# 0    man        True  NaN  Southampton    no  False  (18, 25]
# 1  woman       False    C    Cherbourg   yes  False  (25, 40]
# 2  woman       False  NaN  Southampton   yes   True  (25, 40]
# 3  woman       False    C  Southampton   yes  False  (25, 40]
# 4    man        True  NaN  Southampton    no   True  (25, 40]

# %%
df.pivot_table("survived", ["sex", "new_age"], ["embarked", "class"])
# Out:
# embarked                C                      Q                          S  \
# class               First Second     Third First Second     Third     First
# sex    new_age
# female (0, 10]        NaN    1.0  0.833333   NaN    NaN       NaN  0.000000
#        (10, 18]  1.000000    1.0  0.571429   NaN    NaN  0.750000  1.000000
#        (18, 25]  1.000000    1.0  1.000000   NaN    NaN  0.666667  0.888889
#        (25, 40]  1.000000    1.0  1.000000   1.0    1.0  0.000000  1.000000
#        (40, 90]  0.928571    NaN  0.000000   NaN    NaN       NaN  1.000000
# male   (0, 10]        NaN    1.0  1.000000   NaN    NaN  0.000000  1.000000
#        (10, 18]  0.500000    NaN  0.250000   NaN    NaN       NaN  1.000000
#        (18, 25]  0.500000    0.0  0.428571   NaN    NaN  0.000000  0.000000
#        (25, 40]  0.538462    0.0  0.166667   NaN    NaN  0.250000  0.500000
#        (40, 90]  0.333333    NaN  0.000000   0.0    0.0  0.000000  0.264706
#
# embarked
# ...

# %%
df.pivot_table("survived", ["sex"], ["new_age", "class"])
# Out:
# new_age (0, 10]                   (10, 18]                   (18, 25]  \
# class     First Second     Third     First Second     Third     First
# sex
# female      0.0    1.0  0.500000  1.000000    1.0  0.523810  0.941176
# male        1.0    1.0  0.363636  0.666667    0.0  0.103448  0.333333
#
# new_age                      (25, 40]                      (40, 90]            \
# class      Second     Third     First    Second     Third     First    Second
# sex
# female   0.933333  0.500000  1.000000  0.906250  0.464286  0.961538  0.846154
# male     0.047619  0.115385  0.513514  0.071429  0.172043  0.280000  0.095238
#
# new_age
# class       Third
# sex
# female   0.111111
# male     0.064516

# %% [markdown]
# ##### Apply and lambda function

# %%
df["age2"] = df["age"] * 2
df["age3"] = df["age"] * 5
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone   new_age  age2   age3
# 0    man        True  NaN  Southampton    no  False  (18, 25]  44.0  110.0
# 1  woman       False    C    Cherbourg   yes  False  (25, 40]  76.0  190.0
# 2  woman       False  NaN  Southampton   yes   True  (25, 40]  52.0  130.0
# 3  woman       False    C  Southampton   yes  False  (25, 40]  70.0  175.0
# 4    man        True  NaN  Southampton    no   True  (25, 40]  70.0  175.0

# %%
(df["age"]/10).head()
# Out:
# 0    2.2
# 1    3.8
# 2    2.6
# 3    3.5
# 4    3.5
# Name: age, dtype: float64

# %%
(df["age2"]/10).head()
# Out:
# 0    4.4
# 1    7.6
# 2    5.2
# 3    7.0
# 4    7.0
# Name: age2, dtype: float64

# %%
(df["age3"]/10).head()
# Out:
# 0    11.0
# 1    19.0
# 2    13.0
# 3    17.5
# 4    17.5
# Name: age3, dtype: float64

# %%
df.drop("new_age", axis = 1, inplace = True)

# %%
for col in df.columns:
    if "age" in col:
        print(col)
# Out:
# age
# age2
# age3

# %%
for col in df.columns:
    if "age" in col:
        print((df[col]/10).head())
# Out:
# 0    2.2
# 1    3.8
# 2    2.6
# 3    3.5
# 4    3.5
# Name: age, dtype: float64
# 0    4.4
# 1    7.6
# 2    5.2
# 3    7.0
# 4    7.0
# Name: age2, dtype: float64
# 0    11.0
# 1    19.0
# 2    13.0
# 3    17.5
# 4    17.5
# Name: age3, dtype: float64

# %%
for col in df.columns:
    if "age" in col:
        df["col"] = df[col]/10
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age2   age3   col
# 0    man        True  NaN  Southampton    no  False  44.0  110.0  11.0
# 1  woman       False    C    Cherbourg   yes  False  76.0  190.0  19.0
# 2  woman       False  NaN  Southampton   yes   True  52.0  130.0  13.0
# 3  woman       False    C  Southampton   yes  False  70.0  175.0  17.5
# 4    man        True  NaN  Southampton    no   True  70.0  175.0  17.5

# %%
df[["age", "age2","age3"]].apply(lambda x: x/10).head()
# Out:
#    age  age2  age3
# 0  2.2   4.4  11.0
# 1  3.8   7.6  19.0
# 2  2.6   5.2  13.0
# 3  3.5   7.0  17.5
# 4  3.5   7.0  17.5

# %%
df.loc[:, df.columns.str.contains("age")].apply(lambda x: x/10).head()
# Out:
#    age  age2  age3
# 0  2.2   4.4  11.0
# 1  3.8   7.6  19.0
# 2  2.6   5.2  13.0
# 3  3.5   7.0  17.5
# 4  3.5   7.0  17.5

# %%
df.loc[:, df.columns.str.contains("age")].apply(lambda x: ((x - x.mean())- x.std())).head()
# Out:
#          age      age2        age3
# 0 -22.225615 -44.45123 -111.128075
# 1  -6.225615 -12.45123  -31.128075
# 2 -18.225615 -36.45123  -91.128075
# 3  -9.225615 -18.45123  -46.128075
# 4  -9.225615 -18.45123  -46.128075

# %% [markdown]
# ##### Merging dataframe with concat

# %%
import numpy as np

m = np.random.randint(1,30, size = (5,3))

# %%
df1 = pd.DataFrame(m, columns = ["var1", "var2", "var3"])
df2 = df1 + 99

# %%
df3 = pd.concat([df1, df2])
df3 = pd.concat([df1, df2], ignore_index = True)

# %%
df4 = pd.concat([df1, df2], axis = 1)

# %% [markdown]
# ##### Merge dataframe with Merge

# %%
df1 = pd.DataFrame({'employees': ['Mehmet', 'Veli', 'Ayse', 'Fatma'],
                    'group': ['Accounting', 'Engineering', 'Engineering', 'HR']})

df2 = pd.DataFrame({'employees': ['Ayse', 'Ali', 'Veli', 'Fatma'],
                    "start_date": [2010, 2009, 2014, 2019]})

df4 = pd.DataFrame({'group': ["Accounting", "Engineering", "HR"],
                    "manager": ["Caner", "Mustafa", "Berkay"]})

# %%
df3 = pd.merge(df1, df2)

# %%
df3 = pd.merge(df1, df2, on="employees")

# %%
df3 = pd.merge(df3, df4,)
df3
# Out:
#   employees        group  start_date  manager
# 0      Veli  Engineering        2014  Mustafa
# 1      Ayse  Engineering        2010  Mustafa
# 2     Fatma           HR        2019   Berkay
